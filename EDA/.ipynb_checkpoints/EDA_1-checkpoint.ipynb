# %%
import pandas as pd
import numpy as np
import seaborn as sns
import zipfile

# %% [markdown]
# # Unzip the data folder first

# %%
#hc - housing core
#bls - bureal of labor
#ctr - corporate tax rate
#rm -  rent median
#cs - census_starter
#fa - food access
#ue - unemployment
#me - medicare enrollment

df_hc = pd.read_csv('..\..\Go_Daddy_Data\Data\Data\RDC_Inventory_Core_Metrics_County_History.csv')
df_bls = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\bls-emp_by_cfips.xlsx') #Done
df_ctr = pd.read_csv(r'..\..\Go_Daddy_Data\Data\Data\Corporate_tax_rate.csv') #Done
df_rm_FY19 = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\FY2019_50_County_rev.xlsx')
df_rm_FY20 = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\FY2020_50_County_rev.xlsx')
df_rm_FY21 = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\FY2021_50_County.xlsx')
df_rm_FY22 = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\FY2022_FMR_50_county_rev.xlsx')
df_rm_FY23 = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\FY2023_FMR_50_county.xlsx')
df_fa = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\FoodAccessResearchAtlasData2019.xlsx')
df_ue = pd.read_excel(r'..\..\Go_Daddy_Data\Data\Data\Unemployment.xlsx', skiprows=4) #Bianca
df_me = pd.read_csv(r'..\..\Go_Daddy_Data\Data\Data\Medicare_Monthly_Enrollment_September_2022.csv')


df_cs = pd.read_csv('..\Data\data_zip\census_starter.csv') #Done
df_test = pd.read_csv(r'..\Data\data_zip\test.csv')
df_train = pd.read_csv(r'..\Data\data_zip\train.csv')
# Out:
# C:\Users\jacks\AppData\Local\Temp\ipykernel_16532\736578475.py:10: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_hc = pd.read_csv('..\..\Go_Daddy_Data\Data\Data\RDC_Inventory_Core_Metrics_County_History.csv')

# %% [markdown]
# ## Format Census Starter to join into train and test data

# %%
df_cs
df_cs2 = pd.melt(df_cs, id_vars=['cfips'])
df_cs2['Year'] = df_cs2['variable'].str[-4:]
df_cs2['variable'] = df_cs2['variable'].str[:-5]
pd.pivot_table(df_cs2, values='value', index=['cfips', 'Year'], columns=['variable'], aggfunc=np.sum).reset_index()
# Out:
# variable  cfips  Year  median_hh_inc  pct_bb  pct_college  pct_foreign_born  \
# 0          1001  2017        55317.0    76.6         14.5               2.1
# 1          1001  2018        58786.0    78.9         15.9               2.0
# 2          1001  2019        58731.0    80.6         16.1               2.3
# 3          1001  2020        57982.0    82.7         16.7               2.3
# 4          1001  2021        62660.0    85.5         16.4               2.1
# ...         ...   ...            ...     ...          ...               ...
# 15705     56045  2017        59605.0    71.1         14.1               3.8
# 15706     56045  2018        52867.0    73.3         13.5               4.1
# 15707     56045  2019        57031.0    76.8         13.4               1.7
# 15708     56045  2020        53333.0    79.7         12.7               2.3
# 15709     56045  2021        65566.0    81.3         13.9               1.6
#
# variable  pct_it_workers
# 0                    1.3
# 1                    1.1
# 2                    0.7
# 3                    0.6
# 4                    1.1
# ...                  ...
# 15705                0.6
# 15706                0.6
# 15707                0.0
# 15708                0.0
# 15709                0.0
#
# [15710 rows x 7 columns]

# %%
df_cs2 = pd.melt(df_cs, id_vars=['cfips'])
df_cs2['Year'] = df_cs2['variable'].str[-4:]
df_cs2['variable'] = df_cs2['variable'].str[:-5]
df_cs2.sort_values(['cfips']).reset_index(drop=True)
df_cs2 = pd.pivot_table(df_cs2, values='value', index=['cfips', 'Year'], columns=['variable'], aggfunc=np.sum).reset_index()
df_cs2
# Out:
# variable  cfips  Year  median_hh_inc  pct_bb  pct_college  pct_foreign_born  \
# 0          1001  2017        55317.0    76.6         14.5               2.1
# 1          1001  2018        58786.0    78.9         15.9               2.0
# 2          1001  2019        58731.0    80.6         16.1               2.3
# 3          1001  2020        57982.0    82.7         16.7               2.3
# 4          1001  2021        62660.0    85.5         16.4               2.1
# ...         ...   ...            ...     ...          ...               ...
# 15705     56045  2017        59605.0    71.1         14.1               3.8
# 15706     56045  2018        52867.0    73.3         13.5               4.1
# 15707     56045  2019        57031.0    76.8         13.4               1.7
# 15708     56045  2020        53333.0    79.7         12.7               2.3
# 15709     56045  2021        65566.0    81.3         13.9               1.6
#
# variable  pct_it_workers
# 0                    1.3
# 1                    1.1
# 2                    0.7
# 3                    0.6
# 4                    1.1
# ...                  ...
# 15705                0.6
# 15706                0.6
# 15707                0.0
# 15708                0.0
# 15709                0.0
#
# [15710 rows x 7 columns]

# %% [markdown]
# ### df_hc housing core looks like it is already in a joinable format

# %% [markdown]
# ## Format bureal of labor to join into train and test data

# %%
df_bls2 = pd.pivot_table(df_bls, values='value', index=['cfips', 'first_day_of_month'], columns=['measure_type'], aggfunc=np.sum).reset_index()
df_bls2
# Out:
# measure_type  cfips first_day_of_month  Employment  Labor force  Unemployment  \
# 0              1001         2011-01-01     23440.0      25800.0        2360.0
# 1              1001         2011-02-01     23516.0      25850.0        2334.0
# 2              1001         2011-03-01     23643.0      25862.0        2219.0
# 3              1001         2011-04-01     23787.0      25872.0        2085.0
# 4              1001         2011-05-01     23773.0      25863.0        2090.0
# ...             ...                ...         ...          ...           ...
# 87646         17045         2022-06-01         NaN          NaN         318.0
# 87647         17045         2022-07-01         NaN          NaN         352.0
# 87648         17045         2022-08-01         NaN          NaN         327.0
# 87649         17045         2022-09-01         NaN          NaN         281.0
# 87650         17045         2022-10-01         NaN          NaN         302.0
#
# measure_type  Unemployment rate
# 0                           9.1
# 1                           9.0
# 2                           8.6
# 3                           8.1
# 4                           8.1
# ...                         ...
# 87646                       3.6
# 87647                       3.8
# 87648                       3.6
# 87649                       3.2
# 87650                       3.4
#
# [87651 rows x 6 columns]

# %%
df_ctr2 = pd.melt(df_ctr, id_vars=['State'])
df_ctr2
# Out:
#               State variable  value
# 0          Alabama      2008  4.23%
# 1           Alaska      2008  9.40%
# 2          Arizona      2008  6.97%
# 3         Arkansas      2008  6.50%
# 4       California      2008  8.84%
# ..              ...      ...    ...
# 745       Virginia      2022  7.63%
# 746     Washington      2022  6.81%
# 747  West Virginia      2022  6.50%
# 748      Wisconsin      2022  7.90%
# 749        Wyoming      2022  0.00%
#
# [750 rows x 3 columns]

# %%
df_me
#No formatting change needed
# Out:
#        YEAR      MONTH BENE_GEO_LVL BENE_STATE_ABRVTN  \
# 0      2022      April     National                US
# 1      2022      April        State                AL
# 2      2022      April       County                AL
# 3      2022      April       County                AL
# 4      2022      April       County                AL
# ...     ...        ...          ...               ...
# 60036  2021  September       County                VI
# 60037  2021  September       County                VI
# 60038  2021  September       County                VI
# 60039  2021  September        State                UK
# 60040  2021  September        State                FO
#
#                         BENE_STATE_DESC BENE_COUNTY_DESC  BENE_FIPS_CD  \
# 0                              National            Total           NaN
# 1                               Alabama            Total           1.0
# 2                               Alabama          Autauga        1001.0
# 3                               Alabama          Baldwin        1003.0
# 4                               Alabama          Barbour        1005.0
# ...                                 ...              ...           ...
# 60036                    Virgin Islands         St. John       78020.0
# 60037                    Virgin Islands       St. Thomas       78030.0
# 60038                    Virgin Islands          Unknown       78999.0
# 60039                           Unknown          Unknown          99.0
# 60040  Foreign and Other Outlying Areas            Total           NaN
#
#       TOT_BENES ORGNL_MDCR_BENES MA_AND_OTH_BENES  ... AGED_NO_ESRD_BENES  \
# 0      64665615         35102417         29563198  ...           56614798
# 1       1078349           495600           582749  ...             876402
# 2         11492             5150             6342  ...               9099
# 3         58902            27624            31278  ...              51904
# 4          6260             2440             3820  ...               4877
# ...         ...              ...              ...  ...                ...
# 60036       921              745              176  ...                  *
# 60037      9625             6669             2956  ...               8883
# 60038         *                *                *  ...                  *
# 60039         *                *                *  ...                  *
# 60040    502538           498157             4381  ...             488916
#
#       DSBLD_TOT_BENES DSBLD_ESRD_AND_ESRD_ONLY_BENES DSBLD_NO_ESRD_BENES  \
# 0             7752840                         236979             7515861
# 1              196610                           5000              191610
# 2                2339                             55                2284
# 3                6798                            131                6667
# 4                1329                             41                1288
# ...               ...                            ...                 ...
# 60036              47                              *                   *
# 60037             669                             50                 619
# 60038               *                              *                   *
# 60039               *                              *                   *
# 60040           13579                             28               13551
#
#       A_B_TOT_BENES A_B_ORGNL_MDCR_BENES A_B_MA_AND_OTH_BENES  \
# 0          58785851             29255529             29530322
# 1            998869               416218               582651
# 2             10643                 4303                 6340
# 3             55097                23830                31267
# 4              5932                 2113                 3819
# ...             ...                  ...                  ...
# 60036           838                  662                  176
# 60037          8675                 5719                 2956
# 60038             *                    *                    *
# 60039             *                    *                    *
# 60040         48954                44576                 4378
#
#       PRSCRPTN_DRUG_TOT_BENES PRSCRPTN_DRUG_PDP_BENES PRSCRPTN_DRUG_MAPD_BENES
# 0                    50013581                23367558                 26646023
# 1                      822177                  268695                   553482
# 2                        7985                    1829                     6156
# 3                       44841                   15131                    29710
# 4                        5050                    1396                     3654
# ...                       ...                     ...                      ...
# 60036                     470                     299                      171
# 60037                    5792                    2859                     2933
# 60038                       *                       *                        *
# 60039                       *                       *                        *
# 60040                    8757                    4803                     3954
#
# [60041 rows x 22 columns]

# %%
df_ue2 = pd.melt(df_ue, id_vars=['FIPS_code', 'State', 'Area_name'])
df_ue2['Year'] = df_ue2['variable'].str[-4:]
df_ue2['variable'] = df_ue2['variable'].str[:-5]
df_ue2 = pd.pivot_table(df_ue2, values='value', index=['FIPS_code', 'State', 'Area_name', 'Year'], columns=['variable'], aggfunc=np.sum).reset_index()
df_ue2['Year'].max()
# Out:
# '2021'

# %% [markdown]
# Unemployment data on a two year lag. Match the 2021 data with 2023 year, 2020 with 2022 and so on

# %%
df_me
# Out:
#        YEAR      MONTH BENE_GEO_LVL BENE_STATE_ABRVTN  \
# 0      2022      April     National                US
# 1      2022      April        State                AL
# 2      2022      April       County                AL
# 3      2022      April       County                AL
# 4      2022      April       County                AL
# ...     ...        ...          ...               ...
# 60036  2021  September       County                VI
# 60037  2021  September       County                VI
# 60038  2021  September       County                VI
# 60039  2021  September        State                UK
# 60040  2021  September        State                FO
#
#                         BENE_STATE_DESC BENE_COUNTY_DESC  BENE_FIPS_CD  \
# 0                              National            Total           NaN
# 1                               Alabama            Total           1.0
# 2                               Alabama          Autauga        1001.0
# 3                               Alabama          Baldwin        1003.0
# 4                               Alabama          Barbour        1005.0
# ...                                 ...              ...           ...
# 60036                    Virgin Islands         St. John       78020.0
# 60037                    Virgin Islands       St. Thomas       78030.0
# 60038                    Virgin Islands          Unknown       78999.0
# 60039                           Unknown          Unknown          99.0
# 60040  Foreign and Other Outlying Areas            Total           NaN
#
#       TOT_BENES ORGNL_MDCR_BENES MA_AND_OTH_BENES  ... AGED_NO_ESRD_BENES  \
# 0      64665615         35102417         29563198  ...           56614798
# 1       1078349           495600           582749  ...             876402
# 2         11492             5150             6342  ...               9099
# 3         58902            27624            31278  ...              51904
# 4          6260             2440             3820  ...               4877
# ...         ...              ...              ...  ...                ...
# 60036       921              745              176  ...                  *
# 60037      9625             6669             2956  ...               8883
# 60038         *                *                *  ...                  *
# 60039         *                *                *  ...                  *
# 60040    502538           498157             4381  ...             488916
#
#       DSBLD_TOT_BENES DSBLD_ESRD_AND_ESRD_ONLY_BENES DSBLD_NO_ESRD_BENES  \
# 0             7752840                         236979             7515861
# 1              196610                           5000              191610
# 2                2339                             55                2284
# 3                6798                            131                6667
# 4                1329                             41                1288
# ...               ...                            ...                 ...
# 60036              47                              *                   *
# 60037             669                             50                 619
# 60038               *                              *                   *
# 60039               *                              *                   *
# 60040           13579                             28               13551
#
#       A_B_TOT_BENES A_B_ORGNL_MDCR_BENES A_B_MA_AND_OTH_BENES  \
# 0          58785851             29255529             29530322
# 1            998869               416218               582651
# 2             10643                 4303                 6340
# 3             55097                23830                31267
# 4              5932                 2113                 3819
# ...             ...                  ...                  ...
# 60036           838                  662                  176
# 60037          8675                 5719                 2956
# 60038             *                    *                    *
# 60039             *                    *                    *
# 60040         48954                44576                 4378
#
#       PRSCRPTN_DRUG_TOT_BENES PRSCRPTN_DRUG_PDP_BENES PRSCRPTN_DRUG_MAPD_BENES
# 0                    50013581                23367558                 26646023
# 1                      822177                  268695                   553482
# 2                        7985                    1829                     6156
# 3                       44841                   15131                    29710
# 4                        5050                    1396                     3654
# ...                       ...                     ...                      ...
# 60036                     470                     299                      171
# 60037                    5792                    2859                     2933
# 60038                       *                       *                        *
# 60039                       *                       *                        *
# 60040                    8757                    4803                     3954
#
# [60041 rows x 22 columns]

# %%
df_train
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# ...                  ...    ...             ...      ...                ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming         2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming         2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming         2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming         2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming         2022-10-01
#
#         microbusiness_density  active
# 0                    3.007682    1249
# 1                    2.884870    1198
# 2                    3.055843    1269
# 3                    2.993233    1243
# 4                    2.993233    1243
# ...                       ...     ...
# 122260               1.803249     101
# 122261               1.803249     101
# 122262               1.785395     100
# 122263               1.785395     100
# 122264               1.785395     100
#
# [122265 rows x 7 columns]

# %%
df_train['first_day_of_month'] = pd.to_datetime(df_train['first_day_of_month'])

# %%
df_bls2['first_day_of_month_lag'] = df_bls2['first_day_of_month'] + pd.DateOffset(months=12)

# %%
print(df_bls2.dtypes)
print(df_train.dtypes)
# Out:
# measure_type
# cfips                              int64
# first_day_of_month        datetime64[ns]
# Employment                       float64
# Labor force                      float64
# Unemployment                     float64
# Unemployment rate                float64
# first_day_of_month_lag    datetime64[ns]
# dtype: object
# row_id                           object
# cfips                             int64
# county                           object
# state                            object
# first_day_of_month       datetime64[ns]
# microbusiness_density           float64
# active                            int64
# dtype: object

# %%
df_train_bls = df_train.merge(df_bls2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag'], indicator=True)

# %%
df_bls2['first_day_of_month'].max()
# Out:
# Timestamp('2022-11-01 00:00:00')

# %%
df_train_bls
# Out:
#                   row_id  cfips          county    state first_day_of_month_x  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama           2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama           2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama           2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama           2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama           2019-12-01
# ...                  ...    ...             ...      ...                  ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming           2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming           2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming           2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming           2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming           2022-10-01
#
#         microbusiness_density  active first_day_of_month_y  Employment  \
# 0                    3.007682    1249           2018-08-01     25484.0
# 1                    2.884870    1198           2018-09-01     25443.0
# 2                    3.055843    1269           2018-10-01     25614.0
# 3                    2.993233    1243           2018-11-01     25639.0
# 4                    2.993233    1243           2018-12-01     25664.0
# ...                       ...     ...                  ...         ...
# 122260               1.803249     101                  NaT         NaN
# 122261               1.803249     101                  NaT         NaN
# 122262               1.785395     100                  NaT         NaN
# 122263               1.785395     100                  NaT         NaN
# 122264               1.785395     100                  NaT         NaN
#
#         Labor force  Unemployment  Unemployment rate first_day_of_month_lag  \
# 0           26496.0        1012.0                3.8             2019-08-01
# 1           26354.0         911.0                3.5             2019-09-01
# 2           26526.0         912.0                3.4             2019-10-01
# 3           26485.0         846.0                3.2             2019-11-01
# 4           26543.0         879.0                3.3             2019-12-01
# ...             ...           ...                ...                    ...
# 122260          NaN           NaN                NaN                    NaT
# 122261          NaN           NaN                NaN                    NaT
# 122262          NaN           NaN                NaN                    NaT
# 122263          NaN           NaN                NaN                    NaT
# 122264          NaN           NaN                NaN                    NaT
#
#            _merge
# 0            both
# 1            both
# 2            both
# 3            both
# 4            both
# ...           ...
# 122260  left_only
# 122261  left_only
# 122262  left_only
# 122263  left_only
# 122264  left_only
#
# [122265 rows x 14 columns]

# %%
df_train_bls[df_train_bls['Employment'].isnull()]
# Out:
#                   row_id  cfips          county    state first_day_of_month_x  \
# 21294   15005_2019-08-01  15005  Kalawao County   Hawaii           2019-08-01
# 21295   15005_2019-09-01  15005  Kalawao County   Hawaii           2019-09-01
# 21296   15005_2019-10-01  15005  Kalawao County   Hawaii           2019-10-01
# 21297   15005_2019-11-01  15005  Kalawao County   Hawaii           2019-11-01
# 21298   15005_2019-12-01  15005  Kalawao County   Hawaii           2019-12-01
# ...                  ...    ...             ...      ...                  ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming           2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming           2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming           2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming           2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming           2022-10-01
#
#         microbusiness_density  active first_day_of_month_y  Employment  \
# 21294                8.333333       7                  NaT         NaN
# 21295                9.523809       8                  NaT         NaN
# 21296                9.523809       8                  NaT         NaN
# 21297                9.523809       8                  NaT         NaN
# 21298                9.523809       8                  NaT         NaN
# ...                       ...     ...                  ...         ...
# 122260               1.803249     101                  NaT         NaN
# 122261               1.803249     101                  NaT         NaN
# 122262               1.785395     100                  NaT         NaN
# 122263               1.785395     100                  NaT         NaN
# 122264               1.785395     100                  NaT         NaN
#
#         Labor force  Unemployment  Unemployment rate first_day_of_month_lag  \
# 21294           NaN           NaN                NaN                    NaT
# 21295           NaN           NaN                NaN                    NaT
# 21296           NaN           NaN                NaN                    NaT
# 21297           NaN           NaN                NaN                    NaT
# 21298           NaN           NaN                NaN                    NaT
# ...             ...           ...                ...                    ...
# 122260          NaN           NaN                NaN                    NaT
# 122261          NaN           NaN                NaN                    NaT
# 122262          NaN           NaN                NaN                    NaT
# 122263          NaN           NaN                NaN                    NaT
# 122264          NaN           NaN                NaN                    NaT
#
#            _merge
# 21294   left_only
# 21295   left_only
# 21296   left_only
# 21297   left_only
# 21298   left_only
# ...           ...
# 122260  left_only
# 122261  left_only
# 122262  left_only
# 122263  left_only
# 122264  left_only
#
# [98319 rows x 14 columns]

# %%
df_test
# Out:
#                  row_id  cfips first_day_of_month
# 0       1001_2022-11-01   1001         2022-11-01
# 1       1003_2022-11-01   1003         2022-11-01
# 2       1005_2022-11-01   1005         2022-11-01
# 3       1007_2022-11-01   1007         2022-11-01
# 4       1009_2022-11-01   1009         2022-11-01
# ...                 ...    ...                ...
# 25075  56037_2023-06-01  56037         2023-06-01
# 25076  56039_2023-06-01  56039         2023-06-01
# 25077  56041_2023-06-01  56041         2023-06-01
# 25078  56043_2023-06-01  56043         2023-06-01
# 25079  56045_2023-06-01  56045         2023-06-01
#
# [25080 rows x 3 columns]

# %%
bls_test = pd.read_csv(r'..\..\Go_Daddy_Data\Data\Data\bls-emp_by_cfips.csv')

# %%
bls_test
# Out:
#                     series_id  year period    value footnote_codes  cfips  \
# 0        LAUCN010010000000003  1990    M01      6.5            NaN   1001
# 1        LAUCN010010000000003  1990    M02      6.5            NaN   1001
# 2        LAUCN010010000000003  1990    M03      5.7            NaN   1001
# 3        LAUCN010010000000003  1990    M04      6.6            NaN   1001
# 4        LAUCN010010000000003  1990    M05      6.0            NaN   1001
# ...                       ...   ...    ...      ...            ...    ...
# 5483039  LAUCN721530000000006  2022    M06  10162.0            NaN  72153
# 5483040  LAUCN721530000000006  2022    M07   9987.0            NaN  72153
# 5483041  LAUCN721530000000006  2022    M08  10276.0              P  72153
# 5483042  LAUCN721530000000006  2022    M09      NaN              N  72153
# 5483043  LAUCN721530000000006  2022    M10  10522.0              P  72153
#
#         first_day_of_month       measure_type
# 0               1990-01-01  Unemployment rate
# 1               1990-02-01  Unemployment rate
# 2               1990-03-01  Unemployment rate
# 3               1990-04-01  Unemployment rate
# 4               1990-05-01  Unemployment rate
# ...                    ...                ...
# 5483039         2022-06-01        Labor force
# 5483040         2022-07-01        Labor force
# 5483041         2022-08-01        Labor force
# 5483042         2022-09-01        Labor force
# 5483043         2022-10-01        Labor force
#
# [5483044 rows x 8 columns]

# %%
bls_test['cfips'].unique()
# Out:
# array([ 1001,  1003,  1005, ..., 72149, 72151, 72153], dtype=int64)

# %%
df_bls2 = bls_test[bls_test['period'] != 'M13']
#df_bls2['cfips'] = df_bls2['cfips'].astype('object')

# %%
df_bls2_2 = pd.pivot_table(df_bls2, values='value', index=['cfips', 'first_day_of_month'], columns=['measure_type'], aggfunc=np.sum).reset_index()
df_bls2_2
# Out:
# measure_type  cfips first_day_of_month  Employment  Labor force  Unemployment  \
# 0              1001         1990-01-01     15504.0      16582.0        1078.0
# 1              1001         1990-02-01     15515.0      16591.0        1076.0
# 2              1001         1990-03-01     15768.0      16719.0         951.0
# 3              1001         1990-04-01     15787.0      16898.0        1111.0
# 4              1001         1990-05-01     15869.0      16889.0        1020.0
# ...             ...                ...         ...          ...           ...
# 1267790       72153         2022-06-01      9202.0      10162.0         960.0
# 1267791       72153         2022-07-01      9090.0       9987.0         897.0
# 1267792       72153         2022-08-01      9309.0      10276.0         967.0
# 1267793       72153         2022-09-01         0.0          0.0           0.0
# 1267794       72153         2022-10-01      9401.0      10522.0        1121.0
#
# measure_type  Unemployment rate
# 0                           6.5
# 1                           6.5
# 2                           5.7
# 3                           6.6
# 4                           6.0
# ...                         ...
# 1267790                     9.4
# 1267791                     9.0
# 1267792                     9.4
# 1267793                     0.0
# 1267794                    10.7
#
# [1267795 rows x 6 columns]

# %%
df_bls2_2['first_day_of_month'] = pd.to_datetime(df_bls2_2['first_day_of_month'])

# %%
df_bls2_2['first_day_of_month_lag_6'] = df_bls2_2['first_day_of_month'] + pd.DateOffset(months=6)
df_bls2_2['first_day_of_month_lag_7'] = df_bls2_2['first_day_of_month'] + pd.DateOffset(months=7)
df_bls2_2['first_day_of_month_lag_8'] = df_bls2_2['first_day_of_month'] + pd.DateOffset(months=8)
df_bls2_2['first_day_of_month_lag_9'] = df_bls2_2['first_day_of_month'] + pd.DateOffset(months=9)
df_bls2_2['first_day_of_month_lag_10'] = df_bls2_2['first_day_of_month'] + pd.DateOffset(months=10)
df_bls2_2['first_day_of_month_lag_11'] = df_bls2_2['first_day_of_month'] + pd.DateOffset(months=11)
df_bls2_2['first_day_of_month_lag_12'] = df_bls2_2['first_day_of_month'] + pd.DateOffset(months=12)

# %%
df_train_bls6 = df_train.merge(df_bls2_2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag_6'], 
                              indicator=True, suffixes=['_orig', '_bls'])
df_train_bls6 = df_train_bls6[df_train_bls6['Employment'].notnull()]

df_train_bls7 = df_train.merge(df_bls2_2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag_7'], 
                              indicator=True, suffixes=['_orig', '_bls'])
df_train_bls7 = df_train_bls7[df_train_bls7['Employment'].notnull()]

df_train_bls8 = df_train.merge(df_bls2_2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag_8'], 
                              indicator=True, suffixes=['_orig', '_bls'])
df_train_bls8 = df_train_bls8[df_train_bls8['Employment'].notnull()]

df_train_bls9 = df_train.merge(df_bls2_2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag_9'], 
                              indicator=True, suffixes=['_orig', '_bls'])
df_train_bls9 = df_train_bls9[df_train_bls9['Employment'].notnull()]

df_train_bls10 = df_train.merge(df_bls2_2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag_10'], 
                              indicator=True, suffixes=['_orig', '_bls'])
df_train_bls10 = df_train_bls10[df_train_bls10['Employment'].notnull()]

df_train_bls11 = df_train.merge(df_bls2_2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag_11'], 
                              indicator=True, suffixes=['_orig', '_bls'])
df_train_bls11 = df_train_bls11[df_train_bls11['Employment'].notnull()]

df_train_bls12 = df_train.merge(df_bls2_2, how='left', left_on=['cfips', 'first_day_of_month'], right_on=['cfips','first_day_of_month_lag_12'], 
                              indicator=True, suffixes=['_orig', '_bls'])
df_train_bls12 = df_train_bls12[df_train_bls12['Employment'].notnull()]

# %%
df_train_bls6
# Out:
#                   row_id  cfips          county    state  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama
# 1        1001_2019-09-01   1001  Autauga County  Alabama
# 2        1001_2019-10-01   1001  Autauga County  Alabama
# 3        1001_2019-11-01   1001  Autauga County  Alabama
# 4        1001_2019-12-01   1001  Autauga County  Alabama
# ...                  ...    ...             ...      ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming
# 122261  56045_2022-07-01  56045   Weston County  Wyoming
# 122262  56045_2022-08-01  56045   Weston County  Wyoming
# 122263  56045_2022-09-01  56045   Weston County  Wyoming
# 122264  56045_2022-10-01  56045   Weston County  Wyoming
#
#        first_day_of_month_orig  microbusiness_density  active  \
# 0                   2019-08-01               3.007682    1249
# 1                   2019-09-01               2.884870    1198
# 2                   2019-10-01               3.055843    1269
# 3                   2019-11-01               2.993233    1243
# 4                   2019-12-01               2.993233    1243
# ...                        ...                    ...     ...
# 122260              2022-06-01               1.803249     101
# 122261              2022-07-01               1.803249     101
# 122262              2022-08-01               1.785395     100
# 122263              2022-09-01               1.785395     100
# 122264              2022-10-01               1.785395     100
#
#        first_day_of_month_bls  Employment  Labor force  Unemployment  \
# 0                  2019-02-01     25684.0      26590.0         906.0
# 1                  2019-03-01     25742.0      26608.0         866.0
# 2                  2019-04-01     25969.0      26627.0         658.0
# 3                  2019-05-01     26160.0      26792.0         632.0
# 4                  2019-06-01     26042.0      26858.0         816.0
# ...                       ...         ...          ...           ...
# 122260             2021-12-01      3654.0       3742.0          88.0
# 122261             2022-01-01      3631.0       3740.0         109.0
# 122262             2022-02-01      3621.0       3735.0         114.0
# 122263             2022-03-01      3606.0       3722.0         116.0
# 122264             2022-04-01      3607.0       3712.0         105.0
#
#         Unemployment rate first_day_of_month_lag_6 first_day_of_month_lag_7  \
# 0                     3.4               2019-08-01               2019-09-01
# 1                     3.3               2019-09-01               2019-10-01
# 2                     2.5               2019-10-01               2019-11-01
# 3                     2.4               2019-11-01               2019-12-01
# 4                     3.0               2019-12-01               2020-01-01
# ...                   ...                      ...                      ...
# 122260                2.4               2022-06-01               2022-07-01
# 122261                2.9               2022-07-01               2022-08-01
# 122262                3.1               2022-08-01               2022-09-01
# 122263                3.1               2022-09-01               2022-10-01
# 122264                2.8               2022-10-01               2022-11-01
#
#        first_day_of_month_lag_8 first_day_of_month_lag_9  \
# 0                    2019-10-01               2019-11-01
# 1                    2019-11-01               2019-12-01
# 2                    2019-12-01               2020-01-01
# 3                    2020-01-01               2020-02-01
# 4                    2020-02-01               2020-03-01
# ...                         ...                      ...
# 122260               2022-08-01               2022-09-01
# 122261               2022-09-01               2022-10-01
# 122262               2022-10-01               2022-11-01
# 122263               2022-11-01               2022-12-01
# 122264               2022-12-01               2023-01-01
#
#        first_day_of_month_lag_10 first_day_of_month_lag_11  \
# 0                     2019-12-01                2020-01-01
# 1                     2020-01-01                2020-02-01
# 2                     2020-02-01                2020-03-01
# 3                     2020-03-01                2020-04-01
# 4                     2020-04-01                2020-05-01
# ...                          ...                       ...
# 122260                2022-10-01                2022-11-01
# 122261                2022-11-01                2022-12-01
# 122262                2022-12-01                2023-01-01
# 122263                2023-01-01                2023-02-01
# 122264                2023-02-01                2023-03-01
#
#        first_day_of_month_lag_12 _merge
# 0                     2020-02-01   both
# 1                     2020-03-01   both
# 2                     2020-04-01   both
# 3                     2020-05-01   both
# 4                     2020-06-01   both
# ...                          ...    ...
# 122260                2022-12-01   both
# 122261                2023-01-01   both
# 122262                2023-02-01   both
# 122263                2023-03-01   both
# 122264                2023-04-01   both
#
# [122226 rows x 20 columns]

# %%
#6 month lag seems like the best correlations
df_train_bls6[['microbusiness_density', 'Employment', 'Labor force', 'Unemployment', 'Unemployment rate']].corr()
# Out:
#                        microbusiness_density  Employment  Labor force  \
# microbusiness_density               1.000000    0.278992     0.276131
# Employment                          0.278992    1.000000     0.999054
# Labor force                         0.276131    0.999054     1.000000
# Unemployment                        0.196738    0.825855     0.849600
# Unemployment rate                  -0.018429    0.046060     0.058305
#
#                        Unemployment  Unemployment rate
# microbusiness_density      0.196738          -0.018429
# Employment                 0.825855           0.046060
# Labor force                0.849600           0.058305
# Unemployment               1.000000           0.197360
# Unemployment rate          0.197360           1.000000

# %%
import statsmodels.api as sm
from itertools import combinations

vars_list = ['Employment', 'Labor force', 'Unemployment', 'Unemployment rate']
vars_combinations = list(combinations(vars_list, 1)) + list(combinations(vars_list, 2)) + list(combinations(vars_list, 3)) + list(combinations(vars_list, 4))
vars_combinations = [list(tup) for tup in vars_combinations]
print(vars_combinations)

for lists in vars_combinations:
    x = df_train_bls10[lists]
    y = df_train_bls10[['microbusiness_density']]

    x = sm.add_constant(x) # adding a constant

    model = sm.OLS(y, x).fit()

    print(model.summary())
# Out:
# [['Employment'], ['Labor force'], ['Unemployment'], ['Unemployment rate'], ['Employment', 'Labor force'], ['Employment', 'Unemployment'], ['Employment', 'Unemployment rate'], ['Labor force', 'Unemployment'], ['Labor force', 'Unemployment rate'], ['Unemployment', 'Unemployment rate'], ['Employment', 'Labor force', 'Unemployment'], ['Employment', 'Labor force', 'Unemployment rate'], ['Employment', 'Unemployment', 'Unemployment rate'], ['Labor force', 'Unemployment', 'Unemployment rate'], ['Employment', 'Labor force', 'Unemployment', 'Unemployment rate']]
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.078
# Model:                               OLS   Adj. R-squared:                  0.078
# Method:                    Least Squares   F-statistic:                 1.030e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6498e+05
# No. Observations:                 122226   AIC:                         7.300e+05
# Df Residuals:                     122224   BIC:                         7.300e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3845      0.014    235.767      0.000       3.356       3.413
# Employment   8.83e-06    8.7e-08    101.474      0.000    8.66e-06       9e-06
# ==============================================================================
# Omnibus:                   256037.311   Durbin-Watson:                   0.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2217453338.545
# Skew:                          17.829   Prob(JB):                         0.00
# Kurtosis:                     661.895   Cond. No.                     1.73e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.076
# Model:                               OLS   Adj. R-squared:                  0.076
# Method:                    Least Squares   F-statistic:                 1.007e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6508e+05
# No. Observations:                 122226   AIC:                         7.302e+05
# Df Residuals:                     122224   BIC:                         7.302e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           3.3930      0.014    236.352      0.000       3.365       3.421
# Labor force  8.178e-06   8.15e-08    100.348      0.000    8.02e-06    8.34e-06
# ==============================================================================
# Omnibus:                   255755.278   Durbin-Watson:                   0.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2201689563.050
# Skew:                          17.784   Prob(JB):                         0.00
# Kurtosis:                     659.547   Cond. No.                     1.84e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.038
# Model:                               OLS   Adj. R-squared:                  0.038
# Method:                    Least Squares   F-statistic:                     4871.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6753e+05
# No. Observations:                 122226   AIC:                         7.351e+05
# Df Residuals:                     122224   BIC:                         7.351e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.6004      0.014    251.117      0.000       3.572       3.628
# Unemployment  7.551e-05   1.08e-06     69.795      0.000    7.34e-05    7.76e-05
# ==============================================================================
# Omnibus:                   249379.625   Durbin-Watson:                   0.187
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1867134947.865
# Skew:                          16.785   Prob(JB):                         0.00
# Kurtosis:                     607.565   Cond. No.                     1.36e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.000
# Model:                               OLS   Adj. R-squared:                  0.000
# Method:                    Least Squares   F-statistic:                     33.64
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):           6.66e-09
# Time:                           19:49:28   Log-Likelihood:            -3.6991e+05
# No. Observations:                 122226   AIC:                         7.398e+05
# Df Residuals:                     122224   BIC:                         7.398e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.9628      0.029    136.689      0.000       3.906       4.020
# Unemployment rate    -0.0292      0.005     -5.800      0.000      -0.039      -0.019
# ==============================================================================
# Omnibus:                   244006.429   Durbin-Watson:                   0.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1587764354.657
# Skew:                          15.989   Prob(JB):                         0.00
# Kurtosis:                     560.447   Cond. No.                         12.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     5403.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6475e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122223   BIC:                         7.295e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           3.3665      0.014    234.566      0.000       3.338       3.395
# Employment   5.193e-05   1.99e-06     26.081      0.000     4.8e-05    5.58e-05
# Labor force -4.037e-05   1.86e-06    -21.667      0.000    -4.4e-05   -3.67e-05
# ==============================================================================
# Omnibus:                   256651.899   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2253941051.507
# Skew:                          17.927   Prob(JB):                         0.00
# Kurtosis:                     667.299   Cond. No.                     2.53e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.53e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     5403.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6475e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122223   BIC:                         7.295e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.3665      0.014    234.566      0.000       3.338       3.395
# Employment    1.156e-05   1.53e-07     75.546      0.000    1.13e-05    1.19e-05
# Unemployment -4.037e-05   1.86e-06    -21.667      0.000    -4.4e-05   -3.67e-05
# ==============================================================================
# Omnibus:                   256651.899   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2253941051.507
# Skew:                          17.927   Prob(JB):                         0.00
# Kurtosis:                     667.299   Cond. No.                     1.73e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.079
# Model:                               OLS   Adj. R-squared:                  0.079
# Method:                    Least Squares   F-statistic:                     5207.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6493e+05
# No. Observations:                 122226   AIC:                         7.299e+05
# Df Residuals:                     122223   BIC:                         7.299e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.6347      0.028    129.720      0.000       3.580       3.690
# Employment         8.869e-06   8.71e-08    101.870      0.000     8.7e-06    9.04e-06
# Unemployment rate    -0.0502      0.005    -10.394      0.000      -0.060      -0.041
# ==============================================================================
# Omnibus:                   256236.757   Durbin-Watson:                   0.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2228117406.214
# Skew:                          17.861   Prob(JB):                         0.00
# Kurtosis:                     663.478   Cond. No.                     3.41e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     5403.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6475e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122223   BIC:                         7.295e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.3665      0.014    234.566      0.000       3.338       3.395
# Labor force   1.156e-05   1.53e-07     75.546      0.000    1.13e-05    1.19e-05
# Unemployment -5.193e-05   1.99e-06    -26.081      0.000   -5.58e-05    -4.8e-05
# ==============================================================================
# Omnibus:                   256651.899   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2253941051.507
# Skew:                          17.927   Prob(JB):                         0.00
# Kurtosis:                     667.299   Cond. No.                     1.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.077
# Model:                               OLS   Adj. R-squared:                  0.077
# Method:                    Least Squares   F-statistic:                     5107.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6502e+05
# No. Observations:                 122226   AIC:                         7.300e+05
# Df Residuals:                     122223   BIC:                         7.301e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.6716      0.028    131.112      0.000       3.617       3.726
# Labor force         8.23e-06   8.16e-08    100.889      0.000    8.07e-06    8.39e-06
# Unemployment rate    -0.0561      0.005    -11.585      0.000      -0.066      -0.047
# ==============================================================================
# Omnibus:                   255993.596   Durbin-Watson:                   0.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2214534093.150
# Skew:                          17.822   Prob(JB):                         0.00
# Kurtosis:                     661.460   Cond. No.                     3.64e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.64e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.041
# Model:                               OLS   Adj. R-squared:                  0.041
# Method:                    Least Squares   F-statistic:                     2644.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6733e+05
# No. Observations:                 122226   AIC:                         7.347e+05
# Df Residuals:                     122223   BIC:                         7.347e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.0921      0.028    143.865      0.000       4.036       4.148
# Unemployment       7.983e-05    1.1e-06     72.473      0.000    7.77e-05     8.2e-05
# Unemployment rate    -0.1005      0.005    -20.003      0.000      -0.110      -0.091
# ==============================================================================
# Omnibus:                   249915.969   Durbin-Watson:                   0.188
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1897758747.156
# Skew:                          16.866   Prob(JB):                         0.00
# Kurtosis:                     612.509   Cond. No.                     2.73e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.73e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     3602.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6475e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122222   BIC:                         7.295e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.3671      0.015    227.454      0.000       3.338       3.396
# Employment   -3.427e+06   2.12e+07     -0.161      0.872    -4.5e+07    3.82e+07
# Labor force   3.427e+06   2.12e+07      0.161      0.872   -3.82e+07     4.5e+07
# Unemployment -3.427e+06   2.12e+07     -0.161      0.872    -4.5e+07    3.82e+07
# ==============================================================================
# Omnibus:                   256656.088   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2253854190.805
# Skew:                          17.928   Prob(JB):                         0.00
# Kurtosis:                     667.286   Cond. No.                     6.49e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.69e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     3609.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6474e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122222   BIC:                         7.295e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.4792      0.029    119.611      0.000       3.422       3.536
# Employment         4.933e-05   2.07e-06     23.777      0.000    4.53e-05    5.34e-05
# Labor force       -3.792e-05   1.94e-06    -19.519      0.000   -4.17e-05   -3.41e-05
# Unemployment rate    -0.0224      0.005     -4.454      0.000      -0.032      -0.013
# ==============================================================================
# Omnibus:                   256708.168   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2256521271.393
# Skew:                          17.937   Prob(JB):                         0.00
# Kurtosis:                     667.679   Cond. No.                     5.19e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.19e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     3609.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6474e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122222   BIC:                         7.295e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.4792      0.029    119.611      0.000       3.422       3.536
# Employment         1.141e-05   1.57e-07     72.872      0.000    1.11e-05    1.17e-05
# Unemployment      -3.792e-05   1.94e-06    -19.519      0.000   -4.17e-05   -3.41e-05
# Unemployment rate    -0.0224      0.005     -4.454      0.000      -0.032      -0.013
# ==============================================================================
# Omnibus:                   256708.168   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2256521271.393
# Skew:                          17.937   Prob(JB):                         0.00
# Kurtosis:                     667.679   Cond. No.                     3.55e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     3609.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6474e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122222   BIC:                         7.295e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.4792      0.029    119.611      0.000       3.422       3.536
# Labor force        1.141e-05   1.57e-07     72.872      0.000    1.11e-05    1.17e-05
# Unemployment      -4.933e-05   2.07e-06    -23.777      0.000   -5.34e-05   -4.53e-05
# Unemployment rate    -0.0224      0.005     -4.454      0.000      -0.032      -0.013
# ==============================================================================
# Omnibus:                   256708.168   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2256521271.393
# Skew:                          17.937   Prob(JB):                         0.00
# Kurtosis:                     667.679   Cond. No.                     3.79e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.081
# Model:                               OLS   Adj. R-squared:                  0.081
# Method:                    Least Squares   F-statistic:                     2707.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           19:49:28   Log-Likelihood:            -3.6474e+05
# No. Observations:                 122226   AIC:                         7.295e+05
# Df Residuals:                     122221   BIC:                         7.295e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 3.4792      0.029    118.646      0.000       3.422       3.537
# Employment          9.88e+04   2.12e+07      0.005      0.996   -4.14e+07    4.16e+07
# Labor force        -9.88e+04   2.12e+07     -0.005      0.996   -4.16e+07    4.14e+07
# Unemployment        9.88e+04   2.12e+07      0.005      0.996   -4.14e+07    4.16e+07
# Unemployment rate    -0.0224      0.005     -4.454      0.000      -0.032      -0.013
# ==============================================================================
# Omnibus:                   256707.788   Durbin-Watson:                   0.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2256528112.285
# Skew:                          17.937   Prob(JB):                         0.00
# Kurtosis:                     667.680   Cond. No.                     6.47e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# From these OLS Regression results we have decided to keep Employment, Unemployment, and Unemployment rate

# %%
df_train
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# ...                  ...    ...             ...      ...                ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming         2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming         2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming         2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming         2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming         2022-10-01
#
#         microbusiness_density  active
# 0                    3.007682    1249
# 1                    2.884870    1198
# 2                    3.055843    1269
# 3                    2.993233    1243
# 4                    2.993233    1243
# ...                       ...     ...
# 122260               1.803249     101
# 122261               1.803249     101
# 122262               1.785395     100
# 122263               1.785395     100
# 122264               1.785395     100
#
# [122265 rows x 7 columns]

# %%
df_cs2['year_lag'] = (pd.to_datetime(df_cs2['Year']) + pd.DateOffset(years=2)).dt.year
df_cs2
# Out:
# variable  cfips  Year  median_hh_inc  pct_bb  pct_college  pct_foreign_born  \
# 0          1001  2017        55317.0    76.6         14.5               2.1
# 1          1001  2018        58786.0    78.9         15.9               2.0
# 2          1001  2019        58731.0    80.6         16.1               2.3
# 3          1001  2020        57982.0    82.7         16.7               2.3
# 4          1001  2021        62660.0    85.5         16.4               2.1
# ...         ...   ...            ...     ...          ...               ...
# 15705     56045  2017        59605.0    71.1         14.1               3.8
# 15706     56045  2018        52867.0    73.3         13.5               4.1
# 15707     56045  2019        57031.0    76.8         13.4               1.7
# 15708     56045  2020        53333.0    79.7         12.7               2.3
# 15709     56045  2021        65566.0    81.3         13.9               1.6
#
# variable  pct_it_workers  year_lag
# 0                    1.3      2019
# 1                    1.1      2020
# 2                    0.7      2021
# 3                    0.6      2022
# 4                    1.1      2023
# ...                  ...       ...
# 15705                0.6      2019
# 15706                0.6      2020
# 15707                0.0      2021
# 15708                0.0      2022
# 15709                0.0      2023
#
# [15710 rows x 8 columns]

# %%
df_train['year'] = df_train['first_day_of_month'].dt.year
df_train_cs = df_train.merge(df_cs2, how='left', left_on=['cfips', 'year'], right_on=['cfips','year_lag'], 
                              indicator=True, suffixes=['_orig', '_cps'])
df_train_cs
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# ...                  ...    ...             ...      ...                ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming         2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming         2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming         2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming         2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming         2022-10-01
#
#         microbusiness_density  active  year  Year  median_hh_inc  pct_bb  \
# 0                    3.007682    1249  2019  2017        55317.0    76.6
# 1                    2.884870    1198  2019  2017        55317.0    76.6
# 2                    3.055843    1269  2019  2017        55317.0    76.6
# 3                    2.993233    1243  2019  2017        55317.0    76.6
# 4                    2.993233    1243  2019  2017        55317.0    76.6
# ...                       ...     ...   ...   ...            ...     ...
# 122260               1.803249     101  2022  2020        53333.0    79.7
# 122261               1.803249     101  2022  2020        53333.0    79.7
# 122262               1.785395     100  2022  2020        53333.0    79.7
# 122263               1.785395     100  2022  2020        53333.0    79.7
# 122264               1.785395     100  2022  2020        53333.0    79.7
#
#         pct_college  pct_foreign_born  pct_it_workers  year_lag _merge
# 0              14.5               2.1             1.3      2019   both
# 1              14.5               2.1             1.3      2019   both
# 2              14.5               2.1             1.3      2019   both
# 3              14.5               2.1             1.3      2019   both
# 4              14.5               2.1             1.3      2019   both
# ...             ...               ...             ...       ...    ...
# 122260         12.7               2.3             0.0      2022   both
# 122261         12.7               2.3             0.0      2022   both
# 122262         12.7               2.3             0.0      2022   both
# 122263         12.7               2.3             0.0      2022   both
# 122264         12.7               2.3             0.0      2022   both
#
# [122265 rows x 16 columns]

# %%
df_train_cs[df_train_cs['median_hh_inc'].isnull()]
# Out:
# Empty DataFrame
# Columns: [row_id, cfips, county, state, first_day_of_month, microbusiness_density, active, year, Year, median_hh_inc, pct_bb, pct_college, pct_foreign_born, pct_it_workers, year_lag, _merge]
# Index: []

# %%
df_train_cs[['microbusiness_density', 'median_hh_inc','pct_bb','pct_college','pct_foreign_born','pct_it_workers']].corr()
# Out:
#                        microbusiness_density  median_hh_inc    pct_bb  \
# microbusiness_density               1.000000       0.378204  0.359595
# median_hh_inc                       0.378204       1.000000  0.732426
# pct_bb                              0.359595       0.732426  1.000000
# pct_college                         0.480311       0.708595  0.656127
# pct_foreign_born                    0.277879       0.375235  0.281933
# pct_it_workers                      0.254915       0.312024  0.282487
#
#                        pct_college  pct_foreign_born  pct_it_workers
# microbusiness_density     0.480311          0.277879        0.254915
# median_hh_inc             0.708595          0.375235        0.312024
# pct_bb                    0.656127          0.281933        0.282487
# pct_college               1.000000          0.327771        0.371154
# pct_foreign_born          0.327771          1.000000        0.210967
# pct_it_workers            0.371154          0.210967        1.000000

# %%
vars_list = ['median_hh_inc','pct_bb','pct_college','pct_foreign_born','pct_it_workers']
vars_combinations = list(combinations(vars_list, 1)) + list(combinations(vars_list, 2)) + list(combinations(vars_list, 3)) + list(combinations(vars_list, 4)) \
                    + list(combinations(vars_list, 5))
vars_combinations = [list(tup) for tup in vars_combinations]
print(vars_combinations)

for lists in vars_combinations:
    x = df_train_cs[lists]
    y = df_train_cs[['microbusiness_density']]

    x = sm.add_constant(x) # adding a constant

    model = sm.OLS(y, x).fit()

    print(model.summary())
# Out:
# [['median_hh_inc'], ['pct_bb'], ['pct_college'], ['pct_foreign_born'], ['pct_it_workers'], ['median_hh_inc', 'pct_bb'], ['median_hh_inc', 'pct_college'], ['median_hh_inc', 'pct_foreign_born'], ['median_hh_inc', 'pct_it_workers'], ['pct_bb', 'pct_college'], ['pct_bb', 'pct_foreign_born'], ['pct_bb', 'pct_it_workers'], ['pct_college', 'pct_foreign_born'], ['pct_college', 'pct_it_workers'], ['pct_foreign_born', 'pct_it_workers'], ['median_hh_inc', 'pct_bb', 'pct_college'], ['median_hh_inc', 'pct_bb', 'pct_foreign_born'], ['median_hh_inc', 'pct_bb', 'pct_it_workers'], ['median_hh_inc', 'pct_college', 'pct_foreign_born'], ['median_hh_inc', 'pct_college', 'pct_it_workers'], ['median_hh_inc', 'pct_foreign_born', 'pct_it_workers'], ['pct_bb', 'pct_college', 'pct_foreign_born'], ['pct_bb', 'pct_college', 'pct_it_workers'], ['pct_bb', 'pct_foreign_born', 'pct_it_workers'], ['pct_college', 'pct_foreign_born', 'pct_it_workers'], ['median_hh_inc', 'pct_bb', 'pct_college', 'pct_foreign_born'], ['median_hh_inc', 'pct_bb', 'pct_college', 'pct_it_workers'], ['median_hh_inc', 'pct_bb', 'pct_foreign_born', 'pct_it_workers'], ['median_hh_inc', 'pct_college', 'pct_foreign_born', 'pct_it_workers'], ['pct_bb', 'pct_college', 'pct_foreign_born', 'pct_it_workers'], ['median_hh_inc', 'pct_bb', 'pct_college', 'pct_foreign_born', 'pct_it_workers']]
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.143
# Model:                               OLS   Adj. R-squared:                  0.143
# Method:                    Least Squares   F-statistic:                 2.041e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.6061e+05
# No. Observations:                 122265   AIC:                         7.212e+05
# Df Residuals:                     122263   BIC:                         7.212e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -3.2311      0.051    -63.254      0.000      -3.331      -3.131
# median_hh_inc     0.0001   9.34e-07    142.854      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                   266143.123   Durbin-Watson:                   0.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2851395246.776
# Skew:                          19.497   Prob(JB):                         0.00
# Kurtosis:                     750.124   Cond. No.                     2.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.129
# Model:                               OLS   Adj. R-squared:                  0.129
# Method:                    Least Squares   F-statistic:                 1.816e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.6158e+05
# No. Observations:                 122265   AIC:                         7.232e+05
# Df Residuals:                     122263   BIC:                         7.232e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -10.4812      0.107    -98.004      0.000     -10.691     -10.272
# pct_bb         0.1915      0.001    134.750      0.000       0.189       0.194
# ==============================================================================
# Omnibus:                   262563.061   Durbin-Watson:                   0.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2614723124.503
# Skew:                          18.887   Prob(JB):                         0.00
# Kurtosis:                     718.423   Cond. No.                         605.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.231
# Model:                               OLS   Adj. R-squared:                  0.231
# Method:                    Least Squares   F-statistic:                 3.666e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5401e+05
# No. Observations:                 122265   AIC:                         7.080e+05
# Df Residuals:                     122263   BIC:                         7.080e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -2.1779      0.034    -64.584      0.000      -2.244      -2.112
# pct_college     0.4216      0.002    191.479      0.000       0.417       0.426
# ==============================================================================
# Omnibus:                   282565.241   Durbin-Watson:                   0.222
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4368167471.205
# Skew:                          22.481   Prob(JB):                         0.00
# Kurtosis:                     927.893   Cond. No.                         41.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.077
# Model:                               OLS   Adj. R-squared:                  0.077
# Method:                    Least Squares   F-statistic:                 1.023e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.6513e+05
# No. Observations:                 122265   AIC:                         7.303e+05
# Df Residuals:                     122263   BIC:                         7.303e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                2.6654      0.018    149.515      0.000       2.630       2.700
# pct_foreign_born     0.2428      0.002    101.147      0.000       0.238       0.248
# ==============================================================================
# Omnibus:                   253806.817   Durbin-Watson:                   0.192
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2106107216.398
# Skew:                          17.457   Prob(JB):                         0.00
# Kurtosis:                     645.027   Cond. No.                         9.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.065
# Model:                               OLS   Adj. R-squared:                  0.065
# Method:                    Least Squares   F-statistic:                     8497.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.6594e+05
# No. Observations:                 122265   AIC:                         7.319e+05
# Df Residuals:                     122263   BIC:                         7.319e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              2.0211      0.024     84.628      0.000       1.974       2.068
# pct_it_workers     1.3252      0.014     92.179      0.000       1.297       1.353
# ==============================================================================
# Omnibus:                   252337.470   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2027535746.183
# Skew:                          17.226   Prob(JB):                         0.00
# Kurtosis:                     632.927   Cond. No.                         3.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.158
# Model:                               OLS   Adj. R-squared:                  0.158
# Method:                    Least Squares   F-statistic:                 1.145e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5955e+05
# No. Observations:                 122265   AIC:                         7.191e+05
# Df Residuals:                     122262   BIC:                         7.191e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -7.8836      0.113    -69.960      0.000      -8.104      -7.663
# median_hh_inc   8.74e-05   1.36e-06     64.257      0.000    8.47e-05    9.01e-05
# pct_bb            0.0949      0.002     46.217      0.000       0.091       0.099
# ==============================================================================
# Omnibus:                   268152.758   Durbin-Watson:                   0.208
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3007757135.011
# Skew:                          19.844   Prob(JB):                         0.00
# Kurtosis:                     770.354   Cond. No.                     4.70e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.7e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.234
# Model:                               OLS   Adj. R-squared:                  0.234
# Method:                    Least Squares   F-statistic:                 1.863e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5378e+05
# No. Observations:                 122265   AIC:                         7.076e+05
# Df Residuals:                     122262   BIC:                         7.076e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -2.9225      0.048    -60.412      0.000      -3.017      -2.828
# median_hh_inc  2.683e-05   1.25e-06     21.429      0.000    2.44e-05    2.93e-05
# pct_college       0.3743      0.003    120.179      0.000       0.368       0.380
# ==============================================================================
# Omnibus:                   283217.599   Durbin-Watson:                   0.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4425258138.405
# Skew:                          22.608   Prob(JB):                         0.00
# Kurtosis:                     933.920   Cond. No.                     2.12e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.12e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.165
# Model:                               OLS   Adj. R-squared:                  0.165
# Method:                    Least Squares   F-statistic:                 1.204e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5905e+05
# No. Observations:                 122265   AIC:                         7.181e+05
# Df Residuals:                     122262   BIC:                         7.181e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -2.7806      0.051    -54.446      0.000      -2.881      -2.681
# median_hh_inc        0.0001   9.95e-07    113.054      0.000       0.000       0.000
# pct_foreign_born     0.1383      0.002     56.113      0.000       0.133       0.143
# ==============================================================================
# Omnibus:                   269331.650   Durbin-Watson:                   0.209
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3106147462.710
# Skew:                          20.050   Prob(JB):                         0.00
# Kurtosis:                     782.816   Cond. No.                     2.14e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.164
# Model:                               OLS   Adj. R-squared:                  0.164
# Method:                    Least Squares   F-statistic:                 1.198e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5911e+05
# No. Observations:                 122265   AIC:                         7.182e+05
# Df Residuals:                     122262   BIC:                         7.183e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -3.4180      0.051    -67.586      0.000      -3.517      -3.319
# median_hh_inc      0.0001   9.71e-07    120.204      0.000       0.000       0.000
# pct_it_workers     0.7885      0.014     55.101      0.000       0.760       0.817
# ==============================================================================
# Omnibus:                   269498.953   Durbin-Watson:                   0.208
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3116417223.015
# Skew:                          20.080   Prob(JB):                         0.00
# Kurtosis:                     784.104   Cond. No.                     2.12e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.12e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.234
# Model:                               OLS   Adj. R-squared:                  0.234
# Method:                    Least Squares   F-statistic:                 1.869e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5374e+05
# No. Observations:                 122265   AIC:                         7.075e+05
# Df Residuals:                     122262   BIC:                         7.075e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -4.6423      0.110    -42.208      0.000      -4.858      -4.427
# pct_bb          0.0416      0.002     23.535      0.000       0.038       0.045
# pct_college     0.3767      0.003    129.385      0.000       0.371       0.382
# ==============================================================================
# Omnibus:                   283043.561   Durbin-Watson:                   0.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4413366826.219
# Skew:                          22.574   Prob(JB):                         0.00
# Kurtosis:                     932.668   Cond. No.                         675.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.163
# Model:                               OLS   Adj. R-squared:                  0.163
# Method:                    Least Squares   F-statistic:                 1.192e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5916e+05
# No. Observations:                 122265   AIC:                         7.183e+05
# Df Residuals:                     122262   BIC:                         7.184e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -9.1268      0.107    -85.615      0.000      -9.336      -8.918
# pct_bb               0.1627      0.001    112.048      0.000       0.160       0.166
# pct_foreign_born     0.1676      0.002     70.315      0.000       0.163       0.172
# ==============================================================================
# Omnibus:                   267870.448   Durbin-Watson:                   0.211
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3012385993.733
# Skew:                          19.790   Prob(JB):                         0.00
# Kurtosis:                     770.951   Cond. No.                         616.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.155
# Model:                               OLS   Adj. R-squared:                  0.155
# Method:                    Least Squares   F-statistic:                 1.120e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5976e+05
# No. Observations:                 122265   AIC:                         7.195e+05
# Df Residuals:                     122262   BIC:                         7.196e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -9.7839      0.106    -92.310      0.000      -9.992      -9.576
# pct_bb             0.1664      0.001    114.027      0.000       0.164       0.169
# pct_it_workers     0.8662      0.014     60.796      0.000       0.838       0.894
# ==============================================================================
# Omnibus:                   266702.232   Durbin-Watson:                   0.208
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2923802330.198
# Skew:                          19.588   Prob(JB):                         0.00
# Kurtosis:                     759.566   Cond. No.                         608.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.247
# Model:                               OLS   Adj. R-squared:                  0.247
# Method:                    Least Squares   F-statistic:                 2.005e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5271e+05
# No. Observations:                 122265   AIC:                         7.054e+05
# Df Residuals:                     122262   BIC:                         7.054e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -2.1853      0.033    -65.500      0.000      -2.251      -2.120
# pct_college          0.3828      0.002    166.005      0.000       0.378       0.387
# pct_foreign_born     0.1179      0.002     51.370      0.000       0.113       0.122
# ==============================================================================
# Omnibus:                   285557.968   Durbin-Watson:                   0.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4689356986.588
# Skew:                          23.065   Prob(JB):                         0.00
# Kurtosis:                     961.316   Cond. No.                         43.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.238
# Model:                               OLS   Adj. R-squared:                  0.237
# Method:                    Least Squares   F-statistic:                 1.904e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5347e+05
# No. Observations:                 122265   AIC:                         7.069e+05
# Df Residuals:                     122262   BIC:                         7.070e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -2.3925      0.034    -69.968      0.000      -2.460      -2.326
# pct_college        0.3927      0.002    166.327      0.000       0.388       0.397
# pct_it_workers     0.4621      0.014     33.052      0.000       0.435       0.490
# ==============================================================================
# Omnibus:                   283824.953   Durbin-Watson:                   0.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4503017949.297
# Skew:                          22.725   Prob(JB):                         0.00
# Kurtosis:                     942.071   Cond. No.                         42.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.118
# Model:                               OLS   Adj. R-squared:                  0.118
# Method:                    Least Squares   F-statistic:                     8143.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.6240e+05
# No. Observations:                 122265   AIC:                         7.248e+05
# Df Residuals:                     122262   BIC:                         7.248e+05
# Df Model:                              2
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.3973      0.024     57.440      0.000       1.350       1.445
# pct_foreign_born     0.2050      0.002     85.335      0.000       0.200       0.210
# pct_it_workers       1.0680      0.014     74.746      0.000       1.040       1.096
# ==============================================================================
# Omnibus:                   260065.930   Durbin-Watson:                   0.199
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2488097862.560
# Skew:                          18.464   Prob(JB):                         0.00
# Kurtosis:                     700.881   Cond. No.                         14.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.235
# Model:                               OLS   Adj. R-squared:                  0.235
# Method:                    Least Squares   F-statistic:                 1.252e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5367e+05
# No. Observations:                 122265   AIC:                         7.074e+05
# Df Residuals:                     122261   BIC:                         7.074e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -4.4125      0.112    -39.448      0.000      -4.632      -4.193
# median_hh_inc  1.609e-05   1.45e-06     11.125      0.000    1.33e-05    1.89e-05
# pct_bb            0.0301      0.002     14.771      0.000       0.026       0.034
# pct_college       0.3606      0.003    111.065      0.000       0.354       0.367
# ==============================================================================
# Omnibus:                   283303.613   Durbin-Watson:                   0.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4435392901.664
# Skew:                          22.625   Prob(JB):                         0.00
# Kurtosis:                     934.986   Cond. No.                     4.90e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.179
# Model:                               OLS   Adj. R-squared:                  0.179
# Method:                    Least Squares   F-statistic:                     8878.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5800e+05
# No. Observations:                 122265   AIC:                         7.160e+05
# Df Residuals:                     122261   BIC:                         7.160e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -7.3745      0.112    -66.059      0.000      -7.593      -7.156
# median_hh_inc     6.726e-05   1.39e-06     48.384      0.000    6.45e-05       7e-05
# pct_bb               0.0936      0.002     46.173      0.000       0.090       0.098
# pct_foreign_born     0.1370      0.002     56.077      0.000       0.132       0.142
# ==============================================================================
# Omnibus:                   271394.642   Durbin-Watson:                   0.213
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3277651772.963
# Skew:                          20.414   Prob(JB):                         0.00
# Kurtosis:                     804.074   Cond. No.                     4.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.176
# Model:                               OLS   Adj. R-squared:                  0.176
# Method:                    Least Squares   F-statistic:                     8694.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5822e+05
# No. Observations:                 122265   AIC:                         7.165e+05
# Df Residuals:                     122261   BIC:                         7.165e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -7.6270      0.112    -68.353      0.000      -7.846      -7.408
# median_hh_inc   7.604e-05   1.36e-06     55.776      0.000    7.34e-05    7.87e-05
# pct_bb             0.0861      0.002     42.238      0.000       0.082       0.090
# pct_it_workers     0.7383      0.014     51.785      0.000       0.710       0.766
# ==============================================================================
# Omnibus:                   271180.133   Durbin-Watson:                   0.211
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3256915298.521
# Skew:                          20.376   Prob(JB):                         0.00
# Kurtosis:                     801.533   Cond. No.                     4.71e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.248
# Model:                               OLS   Adj. R-squared:                  0.248
# Method:                    Least Squares   F-statistic:                 1.342e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5265e+05
# No. Observations:                 122265   AIC:                         7.053e+05
# Df Residuals:                     122261   BIC:                         7.053e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -2.5677      0.048    -52.944      0.000      -2.663      -2.473
# median_hh_inc     1.379e-05   1.27e-06     10.859      0.000    1.13e-05    1.63e-05
# pct_college          0.3603      0.003    116.226      0.000       0.354       0.366
# pct_foreign_born     0.1125      0.002     47.870      0.000       0.108       0.117
# ==============================================================================
# Omnibus:                   285759.441   Durbin-Watson:                   0.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4705722251.748
# Skew:                          23.105   Prob(JB):                         0.00
# Kurtosis:                     962.986   Cond. No.                     2.14e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.240
# Model:                               OLS   Adj. R-squared:                  0.240
# Method:                    Least Squares   F-statistic:                 1.285e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5329e+05
# No. Observations:                 122265   AIC:                         7.066e+05
# Df Residuals:                     122261   BIC:                         7.066e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -3.0458      0.048    -63.011      0.000      -3.141      -2.951
# median_hh_inc   2.387e-05   1.25e-06     19.093      0.000    2.14e-05    2.63e-05
# pct_college        0.3518      0.003    110.538      0.000       0.346       0.358
# pct_it_workers     0.4421      0.014     31.580      0.000       0.415       0.470
# ==============================================================================
# Omnibus:                   284359.079   Durbin-Watson:                   0.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4549818485.594
# Skew:                          22.830   Prob(JB):                         0.00
# Kurtosis:                     946.939   Cond. No.                     2.12e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.12e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.181
# Model:                               OLS   Adj. R-squared:                  0.181
# Method:                    Least Squares   F-statistic:                     9022.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5782e+05
# No. Observations:                 122265   AIC:                         7.156e+05
# Df Residuals:                     122261   BIC:                         7.157e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -2.9917      0.051    -58.967      0.000      -3.091      -2.892
# median_hh_inc     9.941e-05   1.02e-06     97.533      0.000    9.74e-05       0.000
# pct_foreign_born     0.1252      0.002     51.036      0.000       0.120       0.130
# pct_it_workers       0.7110      0.014     49.926      0.000       0.683       0.739
# ==============================================================================
# Omnibus:                   272215.666   Durbin-Watson:                   0.212
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3344129006.329
# Skew:                          20.561   Prob(JB):                         0.00
# Kurtosis:                     812.163   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.249
# Model:                               OLS   Adj. R-squared:                  0.249
# Method:                    Least Squares   F-statistic:                 1.352e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5253e+05
# No. Observations:                 122265   AIC:                         7.051e+05
# Df Residuals:                     122261   BIC:                         7.051e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -4.1666      0.109    -38.111      0.000      -4.381      -3.952
# pct_bb               0.0334      0.002     19.027      0.000       0.030       0.037
# pct_college          0.3480      0.003    118.356      0.000       0.342       0.354
# pct_foreign_born     0.1138      0.002     49.434      0.000       0.109       0.118
# ==============================================================================
# Omnibus:                   285848.079   Durbin-Watson:                   0.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4718055717.467
# Skew:                          23.122   Prob(JB):                         0.00
# Kurtosis:                     964.245   Cond. No.                         679.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.240
# Model:                               OLS   Adj. R-squared:                  0.240
# Method:                    Least Squares   F-statistic:                 1.290e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5323e+05
# No. Observations:                 122265   AIC:                         7.065e+05
# Df Residuals:                     122261   BIC:                         7.065e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -4.6641      0.110    -42.581      0.000      -4.879      -4.449
# pct_bb             0.0384      0.002     21.824      0.000       0.035       0.042
# pct_college        0.3521      0.003    117.392      0.000       0.346       0.358
# pct_it_workers     0.4451      0.014     31.852      0.000       0.418       0.473
# ...
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.252
# Model:                               OLS   Adj. R-squared:                  0.252
# Method:                    Least Squares   F-statistic:                 1.372e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5231e+05
# No. Observations:                 122265   AIC:                         7.046e+05
# Df Residuals:                     122261   BIC:                         7.047e+05
# Df Model:                              3
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -2.3677      0.034    -69.894      0.000      -2.434      -2.301
# pct_college          0.3603      0.002    148.145      0.000       0.356       0.365
# pct_foreign_born     0.1113      0.002     48.392      0.000       0.107       0.116
# pct_it_workers       0.3935      0.014     28.267      0.000       0.366       0.421
# ==============================================================================
# Omnibus:                   286508.058   Durbin-Watson:                   0.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4795597537.886
# Skew:                          23.252   Prob(JB):                         0.00
# Kurtosis:                     972.118   Cond. No.                         45.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.249
# Model:                               OLS   Adj. R-squared:                  0.249
# Method:                    Least Squares   F-statistic:                 1.014e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5252e+05
# No. Observations:                 122265   AIC:                         7.051e+05
# Df Residuals:                     122260   BIC:                         7.051e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -4.1353      0.111    -37.269      0.000      -4.353      -3.918
# median_hh_inc     2.412e-06   1.46e-06      1.651      0.099   -4.51e-07    5.28e-06
# pct_bb               0.0318      0.002     15.704      0.000       0.028       0.036
# pct_college          0.3458      0.003    107.008      0.000       0.339       0.352
# pct_foreign_born     0.1131      0.002     48.171      0.000       0.108       0.118
# ==============================================================================
# Omnibus:                   285868.933   Durbin-Watson:                   0.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4719507622.158
# Skew:                          23.126   Prob(JB):                         0.00
# Kurtosis:                     964.393   Cond. No.                     4.91e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.91e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.241
# Model:                               OLS   Adj. R-squared:                  0.241
# Method:                    Least Squares   F-statistic:                     9706.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5319e+05
# No. Observations:                 122265   AIC:                         7.064e+05
# Df Residuals:                     122260   BIC:                         7.064e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -4.4689      0.111    -40.107      0.000      -4.687      -4.251
# median_hh_inc   1.364e-05   1.44e-06      9.453      0.000    1.08e-05    1.65e-05
# pct_bb             0.0288      0.002     14.173      0.000       0.025       0.033
# pct_college        0.3390      0.003    102.480      0.000       0.332       0.345
# pct_it_workers     0.4380      0.014     31.303      0.000       0.411       0.465
# ==============================================================================
# Omnibus:                   284431.420   Durbin-Watson:                   0.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4558826889.094
# Skew:                          22.844   Prob(JB):                         0.00
# Kurtosis:                     947.874   Cond. No.                     4.90e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.193
# Model:                               OLS   Adj. R-squared:                  0.193
# Method:                    Least Squares   F-statistic:                     7319.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5692e+05
# No. Observations:                 122265   AIC:                         7.139e+05
# Df Residuals:                     122260   BIC:                         7.139e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -7.1894      0.111    -64.929      0.000      -7.406      -6.972
# median_hh_inc     5.886e-05   1.39e-06     42.350      0.000    5.61e-05    6.16e-05
# pct_bb               0.0858      0.002     42.568      0.000       0.082       0.090
# pct_foreign_born     0.1250      0.002     51.311      0.000       0.120       0.130
# pct_it_workers       0.6611      0.014     46.602      0.000       0.633       0.689
# ==============================================================================
# Omnibus:                   273965.765   Durbin-Watson:                   0.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3498687770.419
# Skew:                          20.877   Prob(JB):                         0.00
# Kurtosis:                     830.666   Cond. No.                     4.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.252
# Model:                               OLS   Adj. R-squared:                  0.252
# Method:                    Least Squares   F-statistic:                 1.032e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5226e+05
# No. Observations:                 122265   AIC:                         7.045e+05
# Df Residuals:                     122260   BIC:                         7.046e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -2.6936      0.049    -55.471      0.000      -2.789      -2.598
# median_hh_inc     1.187e-05   1.27e-06      9.365      0.000    9.39e-06    1.44e-05
# pct_college          0.3413      0.003    107.853      0.000       0.335       0.348
# pct_foreign_born     0.1067      0.002     45.392      0.000       0.102       0.111
# pct_it_workers       0.3864      0.014     27.724      0.000       0.359       0.414
# ==============================================================================
# Omnibus:                   286665.373   Durbin-Watson:                   0.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4808153309.024
# Skew:                          23.284   Prob(JB):                         0.00
# Kurtosis:                     973.385   Cond. No.                     2.15e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.254
# Model:                               OLS   Adj. R-squared:                  0.254
# Method:                    Least Squares   F-statistic:                 1.039e+04
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5215e+05
# No. Observations:                 122265   AIC:                         7.043e+05
# Df Residuals:                     122260   BIC:                         7.044e+05
# Df Model:                              4
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -4.2110      0.109    -38.631      0.000      -4.425      -3.997
# pct_bb               0.0312      0.002     17.789      0.000       0.028       0.035
# pct_college          0.3285      0.003    108.916      0.000       0.323       0.334
# pct_foreign_born     0.1077      0.002     46.685      0.000       0.103       0.112
# pct_it_workers       0.3820      0.014     27.446      0.000       0.355       0.409
# ==============================================================================
# Omnibus:                   286753.645   Durbin-Watson:                   0.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4820123063.268
# Skew:                          23.302   Prob(JB):                         0.00
# Kurtosis:                     974.593   Cond. No.                         680.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.254
# Model:                               OLS   Adj. R-squared:                  0.254
# Method:                    Least Squares   F-statistic:                     8316.
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):               0.00
# Time:                           20:06:12   Log-Likelihood:            -3.5215e+05
# No. Observations:                 122265   AIC:                         7.043e+05
# Df Residuals:                     122259   BIC:                         7.044e+05
# Df Model:                              5
# Covariance Type:               nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -4.1985      0.111    -37.946      0.000      -4.415      -3.982
# median_hh_inc      9.63e-07   1.46e-06      0.661      0.509   -1.89e-06    3.82e-06
# pct_bb               0.0305      0.002     15.133      0.000       0.027       0.034
# pct_college          0.3276      0.003     99.619      0.000       0.321       0.334
# pct_foreign_born     0.1074      0.002     45.706      0.000       0.103       0.112
# pct_it_workers       0.3817      0.014     27.404      0.000       0.354       0.409
# ==============================================================================
# Omnibus:                   286761.215   Durbin-Watson:                   0.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4820626387.549
# Skew:                          23.303   Prob(JB):                         0.00
# Kurtosis:                     974.644   Cond. No.                     4.91e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.91e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### we are going to drop median_hh_inc from the analysis due to the .5 p value with the other variables and no increase to R^2 with it inclusion. While median_hh_inc by itself gave a p-value of >.001 its information may be given by the other values which is why the p-value increased with everything together. Also the R^2 did not improve with the inclusion of median_hh_inc.

# %%
print(df_ctr2.dtypes)
df_ctr2['value'] = df_ctr2['value'].str.rstrip('%').astype('float') / 100.0
df_ctr2['year_lag_1'] = (pd.to_datetime(df_ctr2['variable']) + pd.DateOffset(years=1)).dt.year
df_ctr2['year_lag_2'] = (pd.to_datetime(df_ctr2['variable']) + pd.DateOffset(years=2)).dt.year
df_ctr2
# Out:
# State         object
# variable      object
# value         object
# year_lag_1     int64
# year_lag_2     int64
# dtype: object
#              State variable   value  year_lag_1  year_lag_2
# 0          Alabama     2008  0.0423        2009        2010
# 1           Alaska     2008  0.0940        2009        2010
# 2          Arizona     2008  0.0697        2009        2010
# 3         Arkansas     2008  0.0650        2009        2010
# 4       California     2008  0.0884        2009        2010
# ..             ...      ...     ...         ...         ...
# 745       Virginia     2022  0.0763        2023        2024
# 746     Washington     2022  0.0681        2023        2024
# 747  West Virginia     2022  0.0650        2023        2024
# 748      Wisconsin     2022  0.0790        2023        2024
# 749        Wyoming     2022  0.0000        2023        2024
#
# [750 rows x 5 columns]

# %%
df_train['state'] = df_train['state'].astype(str)
df_ctr2['State'] = df_ctr2['State'].str[:-1]
print(df_train['state'].unique())
print(df_ctr2['State'].unique())
#print(df_ctr2['State'].str[:-1])
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %%
df_train_ctr_1 = df_train.merge(df_ctr2, how='left', left_on=['state', 'year'], right_on=['State','year_lag_1'], 
                              indicator=True, suffixes=['_orig', '_ctr'])
df_train_ctr_1
df_train_ctr_2 = df_train.merge(df_ctr2, how='left', left_on=['state', 'year'], right_on=['State','year_lag_2'], 
                              indicator=True, suffixes=['_orig', '_ctr'])
df_train_ctr_2
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# ...                  ...    ...             ...      ...                ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming         2022-06-01
# 122261  56045_2022-07-01  56045   Weston County  Wyoming         2022-07-01
# 122262  56045_2022-08-01  56045   Weston County  Wyoming         2022-08-01
# 122263  56045_2022-09-01  56045   Weston County  Wyoming         2022-09-01
# 122264  56045_2022-10-01  56045   Weston County  Wyoming         2022-10-01
#
#         microbusiness_density  active  year    State variable   value  \
# 0                    3.007682    1249  2019  Alabama     2017  0.0423
# 1                    2.884870    1198  2019  Alabama     2017  0.0423
# 2                    3.055843    1269  2019  Alabama     2017  0.0423
# 3                    2.993233    1243  2019  Alabama     2017  0.0423
# 4                    2.993233    1243  2019  Alabama     2017  0.0423
# ...                       ...     ...   ...      ...      ...     ...
# 122260               1.803249     101  2022  Wyoming     2020  0.0000
# 122261               1.803249     101  2022  Wyoming     2020  0.0000
# 122262               1.785395     100  2022  Wyoming     2020  0.0000
# 122263               1.785395     100  2022  Wyoming     2020  0.0000
# 122264               1.785395     100  2022  Wyoming     2020  0.0000
#
#         year_lag_1  year_lag_2 _merge
# 0           2018.0      2019.0   both
# 1           2018.0      2019.0   both
# 2           2018.0      2019.0   both
# 3           2018.0      2019.0   both
# 4           2018.0      2019.0   both
# ...            ...         ...    ...
# 122260      2021.0      2022.0   both
# 122261      2021.0      2022.0   both
# 122262      2021.0      2022.0   both
# 122263      2021.0      2022.0   both
# 122264      2021.0      2022.0   both
#
# [122265 rows x 14 columns]

# %%
df_train_ctr_1 = df_train_ctr_1[df_train_ctr_1['value'].notnull()]
df_train_ctr_2 = df_train_ctr_2[df_train_ctr_2['value'].notnull()]

# %%
print(df_train_ctr_1[['microbusiness_density', 'value']].corr())
print(df_train_ctr_2[['microbusiness_density', 'value']].corr())
# Out:
#                        microbusiness_density     value
# microbusiness_density               1.000000  0.018312
# value                               0.018312  1.000000
#                        microbusiness_density     value
# microbusiness_density               1.000000  0.014425
# value                               0.014425  1.000000

# %%
vars_list = ['value']
vars_combinations = list(combinations(vars_list, 1))
vars_combinations = [list(tup) for tup in vars_combinations]
print(vars_combinations)

for lists in vars_combinations:
    x = df_train_ctr_1[lists]
    y = df_train_ctr_1[['microbusiness_density']]

    x = sm.add_constant(x) # adding a constant

    model = sm.OLS(y, x).fit()

    print(model.summary())

for lists in vars_combinations:
    x = df_train_ctr_2[lists]
    y = df_train_ctr_2[['microbusiness_density']]

    x = sm.add_constant(x) # adding a constant

    model = sm.OLS(y, x).fit()

    print(model.summary())
# Out:
# [['value']]
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.000
# Model:                               OLS   Adj. R-squared:                  0.000
# Method:                    Least Squares   F-statistic:                     41.00
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):           1.53e-10
# Time:                           21:13:18   Log-Likelihood:            -3.6985e+05
# No. Observations:                 122226   AIC:                         7.397e+05
# Df Residuals:                     122224   BIC:                         7.397e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6292      0.032    112.455      0.000       3.566       3.692
# value          2.7692      0.432      6.403      0.000       1.922       3.617
# ==============================================================================
# Omnibus:                   244356.011   Durbin-Watson:                   0.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1602476448.726
# Skew:                          16.040   Prob(JB):                         0.00
# Kurtosis:                     563.026   Cond. No.                         30.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     microbusiness_density   R-squared:                       0.000
# Model:                               OLS   Adj. R-squared:                  0.000
# Method:                    Least Squares   F-statistic:                     25.44
# Date:                   Sun, 05 Feb 2023   Prob (F-statistic):           4.57e-07
# Time:                           21:13:18   Log-Likelihood:            -3.6986e+05
# No. Observations:                 122226   AIC:                         7.397e+05
# Df Residuals:                     122224   BIC:                         7.397e+05
# Df Model:                              1
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6664      0.033    112.273      0.000       3.602       3.730
# value          2.2065      0.437      5.044      0.000       1.349       3.064
# ==============================================================================
# Omnibus:                   244289.737   Durbin-Watson:                   0.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1599661815.198
# Skew:                          16.030   Prob(JB):                         0.00
# Kurtosis:                     562.534   Cond. No.                         30.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Corporate tax rate has an R^2 of 0 so we should not use it even though there was a indication of correlation
